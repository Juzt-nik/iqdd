# %%
# !find /kaggle/input -maxdepth 4

# %%
# !cp -r /kaggle/input/datasets/just7nik/backend/backend /kaggle/working/backend

# %%
# %cd /kaggle/working/backend

# %%
# !ls

# %%
# !pip install -q -r requirements.txt

# %%
# !python -c "import torch, cv2, numpy, pandas, sklearn; print(torch.__version__, torch.cuda.is_available())"

# %%
# !python scripts/train_cnn.py --manifest data/synthetic/manifest.csv --images_dir data/synthetic/images --clean_dir data/clean --output data/models/cnn --epochs 25 --ae_epochs 25 --batch_size 64 --img_size 224
